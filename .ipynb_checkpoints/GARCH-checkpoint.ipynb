# %%
from discrete_methods import *
from continuous_methods import *
import numpy as np
import matplotlib.pyplot as plt
import pickle
import pandas as pd
from IPython.display import Audio
import itertools
import math

# %%
arch=ARCHProcess([0.001,0.413])

# %%
np.random.seed(34802)
data1=np.exp(arch.simulate(100000))
plt.plot(np.cumprod(data1))

# %%
arch2=ARCHProcess([0.0005,0.413])

# %%
data2=np.exp(arch2.simulate(100000))
dat=np.zeros((2,100000))
dat[0,:] = data1
dat[1,:] = data2
dat
# Out:
# array([[0.96237518, 1.0157071 , 1.02241424, ..., 0.95574078, 1.02795191,
#         1.02245075],
#        [0.95859421, 1.03005591, 0.97506892, ..., 0.99505694, 1.05264329,
#         1.03442652]])

# %%
dat=pd.DataFrame(dat,index=['S1','S2'])

# %%
window=1
gamma=0.98
pol=Policy(window,gamma)
pol.train(discretize(dat),decay_rate=0.01)
# Out:
# 1

# %%
pol.q_val
# Out:
# {'[0.96, 0.96]': array([0.02358141, 0.02361531, 0.02363141, 0.02362975, 0.02361035,
#         0.0235731 , 0.02351796, 0.02344505, 0.0233543 , 0.02324578,
#         0.02311946]),
#  '[1.02, 1.03]': array([0.02211007, 0.02222124, 0.02231965, 0.02240531, 0.02247823,
#         0.02253841, 0.02258585, 0.02262057, 0.02264259, 0.02265185,
#         0.02264834]),
#  '[1.02, 0.98]': array([0.02446221, 0.02444072, 0.02440764, 0.0243622 , 0.0243044 ,
#         0.02423422, 0.02415167, 0.02405673, 0.0239494 , 0.02382966,
#         0.02369749]),
#  '[1.0, 1.0]': array([0.02418622, 0.0241633 , 0.02412944, 0.02408464, 0.02402889,
#         0.02396219, 0.02388453, 0.02379591, 0.02369632, 0.02358574,
#         0.02346416]),
#  '[0.98, 1.02]': array([0.02501376, 0.02501298, 0.02499768, 0.02496884, 0.02492649,
#         0.02487061, 0.02480121, 0.02471828, 0.02462181, 0.02451179,
#         0.02438821]),
#  '[0.96, 0.97]': array([0.02322577, 0.02342085, 0.02360015, 0.02376368, 0.0239114 ,
# ...

# %%
for k in pol.q_val.keys():
    print('State : ',k, '; Action : ', np.argmax(pol.q_val[k]))
# Out:
# State :  [0.96, 0.96] ; Action :  2
# State :  [1.02, 1.03] ; Action :  9
# State :  [1.02, 0.98] ; Action :  0
# State :  [1.0, 1.0] ; Action :  0
# State :  [0.98, 1.02] ; Action :  0
# State :  [0.96, 0.97] ; Action :  10
# State :  [1.01, 1.01] ; Action :  1
# State :  [1.01, 0.99] ; Action :  2
# State :  [0.97, 1.03] ; Action :  6
# State :  [1.02, 1.02] ; Action :  10
# State :  [0.98, 1.04] ; Action :  0
# State :  [0.99, 0.98] ; Action :  10
# State :  [1.04, 1.04] ; Action :  0
# State :  [0.97, 1.04] ; Action :  0
# State :  [1.02, 1.04] ; Action :  10
# State :  [0.97, 0.96] ; Action :  10
# State :  [1.01, 1.04] ; Action :  0
# State :  [1.0, 1.04] ; Action :  3
# State :  [1.03, 0.96] ; Action :  0
# State :  [1.03, 1.04] ; Action :  0
# State :  [1.04, 0.98] ; Action :  0
# State :  [0.96, 0.98] ; Action :  0
# State :  [0.98, 1.03] ; Action :  10
# State :  [0.98, 1.01] ; Action :  10
# State :  [1.01, 0.96] ; Action :  2
# State :  [0.99, 1.0] ; Action :  0
# ...

# %%
Ntest=10000
test1=np.exp(arch.simulate(Ntest))
test2=np.exp(arch2.simulate(Ntest))
test=np.zeros((2,Ntest))
test[0,:] = test1
test[1,:] = test2

res=analysis_result(pol,np.array(test))
plot_result(res)

# %%
Ntest=10000
test11=np.exp(arch.simulate(Ntest))
test21=np.exp(arch2.simulate(Ntest))
test1=np.zeros((2,Ntest))
test1[0,:] = test11
test1[1,:] = test21

res1=analysis_result(pol,np.array(test1))
plot_result(res1)

# %% [markdown]
# ## GARCH

# %%
garch=GARCHProcess([1e-5,0.12,0.8316])
gar_data=np.exp(garch.simulate(100000))
plt.plot(np.cumprod(gar_data))

# %%
plt.plot(gar_data)

# %%
garch2=GARCHProcess([1e-5,0.02,0.8316])
gar_data2=np.exp(garch2.simulate(100000))
plt.plot(np.cumprod(gar_data2))

# %%
train_garch = np.zeros((2,100000))
train_garch[0,:] = gar_data
train_garch[1,:] = gar_data2
train_garch= pd.DataFrame(train_garch,index=['S1','S2'])

# %%
window=1
gamma=0.98
pol_garch=Policy(window,gamma)
pol_garch.train(discretize(train_garch),decay_rate=0.01)
# Out:
# 1

# %%
Ntest=10000
test1_garch=np.exp(garch.simulate(Ntest))
test2_garch=np.exp(garch2.simulate(Ntest))
test_garch=np.zeros((2,Ntest))
test_garch[0,:] = test1_garch
test_garch[1,:] = test2_garch

res_garch=analysis_result(pol_garch,np.array(test_garch))
plot_result(res_garch)

# %%
Ntest=10000
test1_garch=np.exp(garch.simulate(Ntest))
test2_garch=np.exp(garch2.simulate(Ntest))
test_garch=np.zeros((2,Ntest))
test_garch[0,:] = test1_garch
test_garch[1,:] = test2_garch

res_garch=analysis_result(pol_garch,np.array(test_garch))
plot_result(res_garch)

# %%
for i in range(10):
    np.random.seed(np.random.randint(1000000))
    Ntest=10000
    test1_garch=np.exp(garch.simulate(Ntest))
    test2_garch=np.exp(garch2.simulate(Ntest))
    test_garch=np.zeros((2,Ntest))
    test_garch[0,:] = test1_garch
    test_garch[1,:] = test2_garch
    
    

    res_garch=analysis_result(pol_garch,np.array(test_garch))
    plot_result(res_garch)

# %%
class corr_GARCH2d:
    def __init__(self,omega,alpha, beta,corr=0,mean=[0,0]):
        self.omega=omega
        self.alpha=alpha
        self.beta = beta
        self.corr=corr
        self.mean=np.array(mean).reshape(-1,1)

    def simulate(self,nb_samples):
        samples = np.zeros((2, nb_samples + 100))
        z = np.random.randn(2, nb_samples + 100)

        previous_sig1 = self.omega[0] / (1 - self.alpha[0] - self.beta[0])
        previous_sig2 = self.omega[1] / (1 - self.alpha[1] - self.beta[1])
        samples[:, 0] = np.squeeze(self.mean + np.matmul(np.matmul(np.matmul(np.diag([previous_sig1,previous_sig2]), np.array([[1,self.corr],[self.corr,1]])),np.diag([previous_sig1,previous_sig2])),np.random.randn(2,1)))
        for i in range(1, nb_samples + 100):
            previous_sig1 = self.omega[0] + self.alpha[0]*(samples[0,i-1]-self.mean[0,0])**2 + self.beta[0]*previous_sig1**2
            previous_sig2 = self.omega[1] + self.alpha[1]*(samples[1,i-1]-self.mean[1,0])**2 + self.beta[1]*previous_sig2**2

            cov=np.matmul(np.matmul(np.diag([previous_sig1,previous_sig2]), np.array([[1,self.corr],[self.corr,1]])),np.diag([previous_sig1,previous_sig2]))
            samples[:, i] = np.squeeze(self.mean + np.matmul(scipy.linalg.cholesky(cov), z[:, i].reshape(-1,1)))

        return samples[:, 100:]

# %%
corr_garch=corr_GARCH2d([0.0072,0.0071],[0.3595,0.3469],[0.8067,0.8757],corr=0.9)

# %%
corr_dat=np.exp(corr_garch.simulate(100000))
plt.plot(np.cumprod(corr_dat[0,:]))
plt.plot(np.cumprod(corr_dat[1,:]))
plt.legend(['S1','S2'])
plt.show()

# %%
window=1
gamma=0.98
pol=Policy(window,gamma)

pol.train(discretize(pd.DataFrame(corr_dat,index=['S1','S2'])),decay_rate=0.1)
# Out:
# 1

# %%
corr_test=np.exp(corr_garch.simulate(10000))
res=analysis_result(pol,np.array(corr_test))
plot_result(res)

# %%
for k in pol.q_val.keys():
    print(k, ' : Optimal action : ', np.argmax(pol.q_val[k]))
# Out:
# [1.0, 1.0]  : Optimal action :  4
# [1.02, 1.0]  : Optimal action :  3
# [1.01, 1.0]  : Optimal action :  10
# [0.99, 1.0]  : Optimal action :  3
# [0.98, 0.99]  : Optimal action :  10
# [0.99, 0.99]  : Optimal action :  0
# [0.98, 1.0]  : Optimal action :  0
# [1.01, 1.01]  : Optimal action :  10
# [1.02, 1.01]  : Optimal action :  0
# [1.0, 1.01]  : Optimal action :  0
# [1.03, 1.01]  : Optimal action :  0
# [0.97, 1.0]  : Optimal action :  0
# [1.03, 1.0]  : Optimal action :  0
# [1.0, 0.99]  : Optimal action :  10
# [0.96, 0.99]  : Optimal action :  0
# [1.01, 0.99]  : Optimal action :  10
# [0.97, 0.99]  : Optimal action :  0
# [0.99, 1.01]  : Optimal action :  0
# [1.04, 1.01]  : Optimal action :  0
# [0.96, 1.0]  : Optimal action :  0
# [1.04, 1.0]  : Optimal action :  10

# %% [markdown]
# ## Delay by one time step

# %%
class DQN2:
    def __init__(self, train_data,window=1, nb_asset=2, nb_action=11,gamma=0.98,batch_size=32,lr=0.1,units1=64,units2=64,last_activation='relu',nb_epochs=1):
        self.window=window
        self.lr=lr
        self.batch_size = batch_size
        self.last_activation=last_activation
        self.units1=units1
        self.units2=units2
        self.nb_epochs=nb_epochs
        self.nb_asset = nb_asset
        self.nb_action = nb_action
        self.model = self.build_model()
        self.train_data = train_data
        self.gamma = gamma
        self.target_model = self.build_model()
        self.update_target_model()

    def build_model(self):
        inp = tf.keras.layers.Input(shape=(self.nb_asset,), name="Prev_ret")
        lay = tf.keras.layers.Dense(units=self.units1, activation='relu', name='Dense_1')(inp)
        lay = tf.keras.layers.Dense(units=self.units2, activation='relu', name='Dense_2')(lay)
        q_val = tf.keras.layers.Dense(units=self.nb_action, activation=self.last_activation, name='linear',kernel_initializer=keras.initializers.Ones(),bias_initializer=keras.initializers.Zeros())(lay)

        optimizer = tf.keras.optimizers.Adam(learning_rate=self.lr)

        model = tf.keras.models.Model(inp, q_val)
        model.compile(loss='mse', optimizer=optimizer)
        model.summary()
        return model

    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    def chooseW(self, state):
        q_val = self.model.predict(state)[0]
        print(q_val)
        w = np.argmax(q_val) / (self.nb_action - 1)
        return w

    def train(self):

        nb_episode = int(np.floor(self.train_data.shape[1]) / self.batch_size)
        print(nb_episode)
        
        for e in range(nb_episode - 1):

            update_input = np.array(self.train_data.iloc[:, e * self.batch_size:(e + 1) * self.batch_size]).transpose()

            update_nextstate = np.array(
                self.train_data.iloc[:, e * self.batch_size + 1:(e + 1) * self.batch_size + 1]).transpose()

            # q_val = self.model.predict(update_input)

            q_val_next = self.target_model.predict(update_nextstate)
            #q_val_next = self.model.predict(update_nextstate)
            q_val = np.zeros((self.batch_size,self.nb_action))
            for i in range(self.batch_size):
                for a in range(self.nb_action):
                    rew_temp = np.dot(np.array([[a / (self.nb_action - 1)], [1 - a / (self.nb_action - 1)]]).transpose(),
                                      update_nextstate[i,:])[0]
                    q_val[i,a] = np.log(rew_temp) + self.gamma * np.max(q_val_next[i,:])

            self.model.fit(update_input, q_val,batch_size=self.batch_size, epochs = self.nb_epochs , verbose=0)
            self.update_target_model()

    def exploit(self, test_data,test=True, init_inv=100):
        w = np.zeros((2, test_data.shape[1] - 1))
        w[0, :] = np.argmax(self.model.predict(np.array(test_data.iloc[:, :-1]).transpose()),axis=1) / (self.nb_action - 1)
        w[1, :] = 1 - w[0, :]

        # ret = np.sum(w * test_data.iloc[:, 1:])
        # plt.plot(np.cumprod(ret))
        # plt.plot(np.cumprod(test_data.iloc[0,:]))
        # plt.plot(np.cumprod(test_data.iloc[1,:]))
        # plt.legend(['Trained policy','S1','S2'])
        # plt.show()

        return w

    def compare_DQN2_discrete(self, true_qval):
        states = np.zeros((2, len(true_qval.keys())))
        for i in range(len(true_qval.keys())):
            states[:, i] = np.array(json.loads(list(true_qval.keys())[i]))

        pred = self.model.predict(states.transpose())
        
        estimated_qval = dict()
        for i in range(len(true_qval.keys())):
            estimated_qval[list(true_qval.keys())[i]] = pred[i, :]

        # print(estimated_qval)

        return conv_qtables(true_qval, estimated_qval)

# %%
corr_data_del=delay_simulation(corr_dat,delay=1)

# %%
actor_corrdel= DQN2(pd.DataFrame(corr_data_del,index=['S1','S2']),batch_size=32,nb_epochs=100,lr=0.001)
actor_corrdel.train()
test_ret_corrdel=delay_simulation(np.exp(corr_garch.simulate(10000)),delay=1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Prev_ret (InputLayer)       [(None, 2)]               0
#
#  Dense_1 (Dense)             (None, 64)                192
#
#  Dense_2 (Dense)             (None, 64)                4160
#
#  linear (Dense)              (None, 11)                715
#
# ...
# Total params: 5,067
# Trainable params: 5,067
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Prev_ret (InputLayer)       [(None, 2)]               0
#
#  Dense_1 (Dense)             (None, 64)                192
#
#  Dense_2 (Dense)             (None, 64)                4160
#
#  linear (Dense)              (None, 11)                715
#
# ...
# Total params: 5,067
# Trainable params: 5,067
# ...

# %%
res_corrdel=analysis_result(actor_corrdel,np.array(test_ret_corrdel))
plot_result(res_corrdel)
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %%
window=1
gamma=0.98
pol_del=Policy(window,gamma)

pol_del.train(discretize(pd.DataFrame(corr_data_del,index=['S1','S2'])),decay_rate=0.001)
# Out:
# 1

# %%
res_del=analysis_result(pol_del,discretize(np.array(test_ret_corrdel)))
plot_result(res_del)

# %%
pol_del.q_val
# Out:
# {'[1.0, 1.0]': array([0.05164233, 0.05164057, 0.05163785, 0.0516341 , 0.0516294 ,
#         0.05162369, 0.05161697, 0.05160924, 0.05160049, 0.05159074,
#         0.05157998]),
#  '[1.02, 1.0]': array([0.05310368, 0.05307488, 0.05304515, 0.0530145 , 0.05298285,
#         0.05295019, 0.05291658, 0.05288207, 0.05284673, 0.05281121,
#         0.05277625]),
#  '[1.01, 1.0]': array([0.05139272, 0.05143218, 0.05147084, 0.05150861, 0.05154546,
#         0.05158139, 0.05161639, 0.0516505 , 0.05168389, 0.05171664,
#         0.05175022]),
#  '[0.99, 0.99]': array([0.05213423, 0.05089051, 0.04964698, 0.04840106, 0.04715274,
#         0.04590201, 0.04464885, 0.04339327, 0.04213524, 0.04087476,
#         0.03961182]),
#  '[0.98, 1.0]': array([0.05222027, 0.05215999, 0.05209905, 0.05203696, 0.05197372,
#         0.05190935, 0.05184383, 0.05177717, 0.05170936, 0.05164041,
#         0.05157032]),
#  '[1.01, 0.99]': array([0.05159681, 0.05038378, 0.04916838, 0.0479506 , 0.04673043,
# ...

# %%
for k in pol_del.q_val.keys():
    print(k, ' : Optimal action : ',np.argmax(pol_del.q_val[k]))
# Out:
# [1.0, 1.0]  : Optimal action :  0
# [1.02, 1.0]  : Optimal action :  0
# [1.01, 1.0]  : Optimal action :  10
# [0.99, 0.99]  : Optimal action :  0
# [0.98, 1.0]  : Optimal action :  0
# [1.01, 0.99]  : Optimal action :  0
# [0.99, 1.0]  : Optimal action :  10
# [1.01, 1.01]  : Optimal action :  10
# [0.99, 1.01]  : Optimal action :  10
# [0.98, 1.01]  : Optimal action :  10
# [1.03, 1.0]  : Optimal action :  10
# [1.0, 0.99]  : Optimal action :  0
# [1.0, 1.01]  : Optimal action :  10
# [0.97, 1.0]  : Optimal action :  0
# [1.02, 0.99]  : Optimal action :  0
# [0.98, 0.99]  : Optimal action :  0
# [0.96, 1.0]  : Optimal action :  0
# [0.97, 1.01]  : Optimal action :  10
# [1.02, 1.01]  : Optimal action :  10
# [1.03, 0.99]  : Optimal action :  0
# [1.03, 1.01]  : Optimal action :  10
# [1.04, 1.0]  : Optimal action :  10
# [1.04, 1.01]  : Optimal action :  0
# [0.97, 0.99]  : Optimal action :  0
# [1.04, 0.99]  : Optimal action :  0
# [0.96, 1.01]  : Optimal action :  0
# ...

# %%
conv_corrdel=actor_corrdel.compare_DQN2_discrete(pol_del.q_val)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# [[0.14133689 0.14128017 0.14122105 0.14116135 0.14110103 0.14103961
#   0.14097646 0.14091274 0.14084762 0.14078154 0.1407139 ]
#  [0.14128472 0.14119141 0.14109573 0.14100122 0.14090776 0.1408127
#   0.14071344 0.14061072 0.14050394 0.1403939  0.14028046]
#  [0.1413108  0.1412358  0.1411584  0.1410813  0.14100441 0.14092617
#   0.14084497 0.14076176 0.14067581 0.14058776 0.14049721]
#  [0.14197876 0.13982661 0.1376727  0.13551632 0.13335878 0.13120295
#   0.12904717 0.12689126 0.12473358 0.1225742  0.1204122 ]
#  [0.14138906 0.14136896 0.1413464  0.1413215  0.14129432 0.14126654
#   0.1412395  0.14121476 0.14119133 0.14116918 0.1411474 ]
#  [0.14192659 0.13973783 0.13754737 0.13535619 0.13316551 0.13097602
#   0.12878413 0.12658924 0.1243899  0.12218659 0.11997873]
#  [0.14136298 0.14132456 0.14128372 0.14124143 0.14119767 0.14115307
#   0.14110796 0.14106372 0.14101946 0.14097534 0.14093062]
# ...

# %%
plot_error_per_state(conv_corrdel)

# %%
def compare_DQN2_discrete(actor,true_qval):
    states = np.zeros((2, len(true_qval.keys())))
    for i in range(len(true_qval.keys())):
        states[:, i] = np.array(json.loads(list(true_qval.keys())[i]))

    pred = actor.model.predict(states.transpose())

    estimated_qval = dict()
    for i in range(len(true_qval.keys())):
        estimated_qval[list(true_qval.keys())[i]] = pred[i, :]

    for k in true_qval.keys():
        print(k, '; Action from discrete policy : ', np.argmax(true_qval[k]), '; Action from DQN2 algorithm : ', np.argmax(estimated_qval[k]))

    return conv_qtables(true_qval, estimated_qval)

# %%
compare_DQN2_discrete(actor_corrdel,pol_del.q_val)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# [1.0, 1.0] ; Action from discrete policy :  0 ; Action from DQN2 algorithm :  0
# [1.02, 1.0] ; Action from discrete policy :  0 ; Action from DQN2 algorithm :  0
# [1.01, 1.0] ; Action from discrete policy :  10 ; Action from DQN2 algorithm :  0
# [0.99, 0.99] ; Action from discrete policy :  0 ; Action from DQN2 algorithm :  0
# [0.98, 1.0] ; Action from discrete policy :  0 ; Action from DQN2 algorithm :  0
# [1.01, 0.99] ; Action from discrete policy :  0 ; Action from DQN2 algorithm :  0
# [0.99, 1.0] ; Action from discrete policy :  10 ; Action from DQN2 algorithm :  0
# [1.01, 1.01] ; Action from discrete policy :  10 ; Action from DQN2 algorithm :  10
# [0.99, 1.01] ; Action from discrete policy :  10 ; Action from DQN2 algorithm :  10
# [0.98, 1.01] ; Action from discrete policy :  10 ; Action from DQN2 algorithm :  10
# [1.03, 1.0] ; Action from discrete policy :  10 ; Action from DQN2 algorithm :  0
# ...

# %% [markdown]
# ## The DQN2 seems to be better than Q-Learning on the discretized data
# We can see that for state $[1.04, 1.01]$, Q-Learning chooses action $w_1=0$, nevertheless since by definition of the process (i.e. correlation + delay by $1$ time-step), it is more optimal to bet on the first stock for the next time-step, i.e. $w_1=1$ which corresponds to the action chosen by DQN.

# %%
garch_l=GARCHProcess([2.157e-6,0.0623,0.8997])

# %%
d=garch_l.simulate(100000)

# %%
plt.plot(np.cumprod(np.exp(d)))

# %%
class eGARCHProcess:
    def __init__(self,omega,alpha,beta,leverage):
        self.omega = omega
        self.alpha = alpha
        self.beta = beta
        self.leverage = leverage
    def simulate(self,nb_samples):
        samples=np.zeros(nb_samples + 100)
        z = np.random.standard_t(2,nb_samples + 100)
        
        previous_sig = self.omega/(1-self.alpha-self.beta)
        samples[0] = previous_sig * np.random.randn()
        
        for i in range(1,nb_samples + 100):
            previous_sig = np.exp(self.omega + self.alpha * (np.abs(z[i-1])-np.sqrt(2/math.pi))   +  self.beta * np.log(previous_sig)  + self.leverage* z[i-1])

            print(previous_sig)
            samples[i] =  z[i] * np.sqrt(previous_sig)
        return samples[100:]

# %% [markdown]
# # EGARCH still need to look for good parameters

# %%
egarch=eGARCHProcess(-0.053254,0.0615306,0.9924854,0.01)

# %%
plt.plot(np.exp(egarch.simulate(1000)))

# %%
np.exp(4)
# Out:
# 54.598150033144236

# %%
class GARCHProcess:
    def __init__(self, coeffs,distr='normal'):

        if distr=='normal':
            self.distr=distr
        else:
            self.distr='student'

        if coeffs[1]+coeffs[2] < 1:
            self.coeffs = coeffs
        else:
            coeffs_corrected=coeffs
            coeffs_corrected[2]=1-coeffs[1]
            print('Error : coefficient alpha and beta must add to less than one !!')

    def simulate(self, nb_samples):
        samples = np.zeros(nb_samples + 100)
        if self.distr=='normal':
            z = np.random.randn(nb_samples + 100)
            previous_sig=self.coeffs[0] / (1 - self.coeffs[1]-self.coeffs[2])
            samples[0] = np.sqrt(previous_sig) * np.random.randn()
        else:
            z = np.random.standard_t(1,nb_samples + 100 + 1)
            previous_sig=self.coeffs[0] / (1 - self.coeffs[1]-self.coeffs[2])
            samples[0] = np.sqrt(previous_sig) * np.random.standard_t(1)

        for i in range(1, nb_samples + 100):
            previous_sig=self.coeffs[0] + self.coeffs[1] * samples[i - 1] ** 2 + self.coeffs[2] * previous_sig ** 2
            samples[i] = z[i] * np.sqrt(previous_sig)

        return samples[100:]

# %%
gar=GARCHProcess([0.529e-6,0.04111,0.9417])

# %%
plt.plot(np.exp(gar.simulate(1000000)))

# %%
gar1=GARCHProcess([1.4e-6,0.0772,0.9046])

# %%
plt.plot(np.exp(gar1.simulate(1000000)))

# %%
np.array([0,0]).reshape(-1,1)
# Out:
# array([[0],
#        [0]])

# %%
class multi_GARCH:
    def __init__(self,omega,alpha, beta):
        self.omega=omega
        self.alpha=alpha
        self.beta = beta

    def simulate(self,nb_samples):
        samples = np.zeros((self.omega.shape[0], nb_samples + 100))
        z = np.random.randn(self.omega.shape[0], nb_samples + 100)

        previous_sig = np.array([[self.omega[0,0]/(1-self.alpha[0,0]-self.beta[0,0]),0],[0,self.omega[1,1]/(1-self.alpha[1,1]-self.beta[1,1])]])

        samples[:, 0] = np.squeeze(np.matmul(previous_sig,np.random.randn(self.omega.shape[0],1)))
        for i in range(1, nb_samples + 100):
            previous_sig = self.omega + self.alpha * np.matmul(samples[:,i-1].reshape(-1,1),samples[:,i-1].reshape(-1,1).transpose()) + self.beta * previous_sig

            samples[:, i] = np.squeeze(np.matmul(scipy.linalg.cholesky(previous_sig), z[:, i].reshape(-1,1)))

        return samples[:, 100:]

# %%
# Values from : FLEXIBLE MULTIVARIATE GARCH MODELING WITH AN APPLICATION TO INTERNATIONAL STOCK MARKETS
# Only C divided by 100


C=np.array([[0.0001448,0.0001292],[0.0001292, 0.0001641]])
A=np.array([[0.0861,0.0499],[0.0499, 0.0710]])
B=np.array([[0.8835,0.8886],[0.8886, 0.9066]])

m_garch=multi_GARCH(C,A,B)

# %%
plt.plot(np.cumprod(np.exp(m_garch.simulate(10000))[0,:]))

# %%
class diag_BEKK_GARCH:
    def __init__(self,G,E, F):
        self.G=G
        self.E=np.diag(E)
        self.F = np.diag(F)

    def simulate(self,nb_samples):
        samples = np.zeros((self.G.shape[0], nb_samples + 100))
        z = np.random.randn(self.G.shape[0], nb_samples + 100)

        previous_sig = np.matmul(self.G.transpose(),self.G) * np.array([[1/(1-self.E[0,0]**2-self.F[0,0]**2),1],[1,1/(1-self.E[1,1]**2-self.F[1,1]**2)]])

        samples[:, 0] = np.squeeze(np.matmul(previous_sig,np.random.randn(self.G.shape[0],1)))
        for i in range(1, nb_samples + 100):
            previous_sig = np.matmul(self.G.transpose(),self.G) + np.matmul(np.matmul(self.E.transpose(), np.matmul(samples[:,i-1].reshape(-1,1),samples[:,i-1].reshape(-1,1).transpose())),self.E) + np.matmul(np.matmul(self.F.transpose(), previous_sig),self.F)

            samples[:, i] = np.squeeze(np.matmul(scipy.linalg.cholesky(previous_sig), z[:, i].reshape(-1,1)))

        return samples[:, 100:]

# %%
bekk_garch= diag_BEKK_GARCH(np.array([[0.003034,0.001004],[0, 0.001662]]),[0.1446, 0.1283],[0.9786, 0.9885])

# %%
plt.plot(np.cumprod(np.exp(bekk_garch.simulate(10000))[0,:]))
plt.plot(np.cumprod(np.exp(bekk_garch.simulate(10000))[1,:]))
plt.show()

# %%
m_data=np.exp(m_garch.simulate(100000))
plt.plot(np.cumprod(m_data[0,:]))
plt.plot(np.cumprod(m_data[1,:]))
plt.legend(['S1','S2'])
plt.show()

# %%
m_actor=DQN2(pd.DataFrame(m_data,index=['S1','S2']),batch_size=32,nb_epochs=100,lr=0.01)
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Prev_ret (InputLayer)       [(None, 2)]               0
#
#  Dense_1 (Dense)             (None, 64)                192
#
#  Dense_2 (Dense)             (None, 64)                4160
#
#  linear (Dense)              (None, 11)                715
#
# ...
# Total params: 5,067
# Trainable params: 5,067
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Prev_ret (InputLayer)       [(None, 2)]               0
#
#  Dense_1 (Dense)             (None, 64)                192
#
#  Dense_2 (Dense)             (None, 64)                4160
#
#  linear (Dense)              (None, 11)                715
#
# ...
# Total params: 5,067
# Trainable params: 5,067
# ...

# %%
m_actor.train()
test_m=np.exp(m_garch.simulate(10000))
res_m=analysis_result(m_actor,np.array(test_m))
plot_result(res_m)
# Out:
# 3125
# ...
# 1/1 [==============================] - 0s 23ms/step
# ...
# ...
# 313/313 [==============================] - 0s 1ms/step

# %%
window=1
gamma=0.98
pol_m=Policy(window,gamma)

pol_m.train(discretize(pd.DataFrame(m_data,index=['S1','S2'])),decay_rate=0.001)
# Out:
# 1

# %%
res_m_pol=analysis_result(pol_m,discretize(np.array(test_m)))
plot_result(res_m_pol)

# %%
conv_m=compare_DQN2_discrete(m_actor,pol_m.q_val)
# Out:
# 3/3 [==============================] - 0s 4ms/step
# [0.96, 1.04] ; Action from discrete policy :  0 ; Action from DQN2 algorithm :  10
# [0.96, 0.98] ; Action from discrete policy :  6 ; Action from DQN2 algorithm :  10
# [1.04, 0.96] ; Action from discrete policy :  0 ; Action from DQN2 algorithm :  10
# [0.97, 0.96] ; Action from discrete policy :  0 ; Action from DQN2 algorithm :  10
# [1.01, 0.96] ; Action from discrete policy :  0 ; Action from DQN2 algorithm :  10
# [0.96, 1.0] ; Action from discrete policy :  10 ; Action from DQN2 algorithm :  10
# [0.97, 1.04] ; Action from discrete policy :  0 ; Action from DQN2 algorithm :  10
# [0.96, 0.96] ; Action from discrete policy :  0 ; Action from DQN2 algorithm :  10
# [1.0, 1.03] ; Action from discrete policy :  0 ; Action from DQN2 algorithm :  10
# [0.96, 1.01] ; Action from discrete policy :  0 ; Action from DQN2 algorithm :  10
# [0.99, 1.02] ; Action from discrete policy :  5 ; Action from DQN2 algorithm :  10
# ...

# %%
plot_error_per_state(conv_m)

# %%
conv_m
# Out:
# {'max': 0.1754878584269796,
#  'nb_wrong': 51,
#  'Frobenius': 4.932496405156899,
#  'state_max': {'[0.96, 1.04]': 0.17509239638481133,
#   '[0.96, 0.98]': 0.16725026011986993,
#   '[1.04, 0.96]': 0.17043260720605846,
#   '[0.97, 0.96]': 0.1717086399384214,
#   '[1.01, 0.96]': 0.16826115259667743,
#   '[0.96, 1.0]': 0.1698112173145342,
#   '[0.97, 1.04]': 0.16976887330569962,
#   '[0.96, 0.96]': 0.1743108243640562,
#   '[1.0, 1.03]': 0.17020300712823044,
#   '[0.96, 1.01]': 0.16949566642116126,
#   '[0.99, 1.02]': 0.16729508976418314,
#   '[1.0, 0.96]': 0.17039582685499854,
#   '[1.02, 1.03]': 0.16398536488212012,
#   '[1.04, 1.04]': 0.1754878584269796,
#   '[1.04, 1.0]': 0.1751613816793201,
#   '[1.0, 1.02]': 0.16409874595464596,
#   '[0.99, 0.96]': 0.16932433681279985,
#   '[0.98, 1.03]': 0.16610686008428194,
#   '[0.96, 0.97]': 0.1681258926063294,
#   '[1.03, 1.04]': 0.17001500875001527,
#   '[0.96, 1.03]': 0.17010376345051378,
#   '[1.04, 1.02]': 0.1719935543365396,
# ...
